# %% [markdown]
# <a href="https://colab.research.google.com/github/lexoz-bedra/cs102/blob/homework06/part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Дескриптивный анализ данных

# %% [markdown]
# В этой практической работе вам предстоит провести анализ данных об особенностях жанров музыки. Датасет возьмите [отсюда](https://www.kaggle.com/vicsuperman/prediction-of-music-genre). Он содержит 41700 уникальных исполниителей.
#
# Данные содержат 18 столбцов:
# - `instance_id` - id строки датасета
# - `artist_name` - исполнитель
# - `track_name` - название трека
# - `popularity` - индекс популярности трека
# - `acousticness` - акустичность
# - `danceability` - танцевальность (насколько трек подходит для танцев)
# - `duration_ms` - длительность трека
# - `energy` - энергичность трека
# - `instrumentalness` - инструментальность
# - `key` - регистр (высота тона)
# - `liveness` - живость
# - `loudness` - громкость
# - `mode` - тональность
# - `speechiness` - насколько много текста
# - `tempo` - музыкальный темп
# - `obtained_date` - дата загрузки трека в датасет
# - `valence` - настроение
# - `music_genre` - жанр

# %% [markdown]
# ## Часть 2

# %% [markdown]
# Выполните на языке R следующие задания:
# - задание 1 – целиком
# - задание 2 – целиком
# - задание 3 – целиком
# - задание 4 – целиком
# - задание 5 – целиком
# - задание 6 – не выполнять
# - задание 7 – целиком
# - задание 8 – целиком, но в третьем пункте постройте круговую диаграмму

# %% [markdown]
# ### Задание 1

# %% [markdown]
# 1. Загрузите датасет `music_genre.csv`.
# 2. Возьмите 20 тысяч случайных строк из датасета (**все остальные задания выполняйте для этих 20 тысяч строк!!!**)
# 3. Проверьте, есть ли в датасете дублирующиеся строки. Если есть, удалите их.
# 4. Проверьте, есть ли а датасете строки, в которых значение в столбце `artist_name` – `empty_field`. Если есть, выведите эти строки и их количество. А затем удалите из датасета.

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# загружаем датасет
genres <- read.csv("https://drive.google.com/uc?export=download&confirm=no_antivirus&id=1jogqyngwmQg6fzr_1PolQOFhDyNGSAza")
head(genres)
# Out:
#   instance_id artist_name          track_name           popularity acousticness
# 1 32894       Röyksopp             Röyksopp's Night Out 27         0.00468
# 2 46652       Thievery Corporation The Shining Path     31         0.01270
# 3 30097       Dillon Francis       Hurricane            28         0.00306
# 4 62177       Dubloadz             Nitro                34         0.02540
# 5 24907       What So Not          Divide & Conquer     32         0.00465
# 6 89064       Axel Boman           Hello                47         0.00523
#   danceability duration_ms energy instrumentalness key liveness loudness mode
# 1 0.652            -1      0.941  0.79200          A#  0.115     -5.201  Minor
# 2 0.622        218293      0.890  0.95000          D   0.124     -7.043  Minor
# 3 0.620        215613      0.755  0.01180          G#  0.534     -4.617  Major
# 4 0.774        166875      0.700  0.00253          C#  0.157     -4.498  Major
# 5 0.638        222369      0.587  0.90900          F#  0.157     -6.266  Major
# 6 0.755        519468      0.731  0.85400          D   0.216    -10.517  Minor
#   speechiness tempo              obtained_date valence music_genre
# 1 0.0748      100.889            4-Apr         0.759   Electronic
# 2 0.0300      115.00200000000001 4-Apr         0.531   Electronic
# 3 0.0345      127.994            4-Apr         0.333   Electronic
# 4 0.2390      128.014            4-Apr         0.270   Electronic
# 5 0.0413      145.036            4-Apr         0.323   Electronic
#       valence music_genre
# 31722 0.2580  Blues
# 4483  0.0883  Electronic
# 14674 0.8190  Jazz
# 37571 0.7850  Rock
# 47583 0.1410  Hip-Hop
# 29473 0.0703  Rap
# 37204 0.3230  Rock
# 34901 0.4830  Blues
# 33883 0.1640  Blues
# 31371 0.6780  Blues
# 40880 0.0510  Classical
# 45697 0.1340  Hip-Hop
# 14314 0.3650  Jazz
# 22268 0.4540  Country
# 32976 0.9480  Blues
# 43483 0.3210  Classical
# 12678 0.7340  Jazz
# 8077  0.8090  Anime
# 47265 0.2140  Hip-Hop
# 19097 0.3940  Alternative
# 8641  0.3820  Anime
# 32062 0.7160  Blues
# 38170 0.3700  Rock
# 38079 0.3040  Rock
# 49952 0.4930  Hip-Hop
# 5843  0.6540  Anime
# 5710  0.3210  Anime
# 39491 0.7160  Rock
# 39866 0.8580  Rock
# 11649 0.7560  Jazz
# ⋮     ⋮       ⋮
# 38803 0.9020  Rock
# 30321 0.4250  Blues
# 21208 0.8710  Country
# 22725 0.5880  Country
# 16576 0.3490  Alternative
# 9864  0.6080  Anime
# 10007 0.2870  Jazz
# 42644 0.1000  Classical
# 3148  0.3620  Electronic
# 45155 0.1370  Hip-Hop
# 17861 0.6530  Alternative
# 17494 0.2290  Alternative
# 27903 0.9610  Rap
# 7653  0.6160  Anime
# 5662  0.6990  Anime
# 20091 0.6530  Country
# 40953 0.3530  Classical
# 34228 0.7380  Blues
# 24272 0.5210  Country
# 37692 0.7360  Rock
# 46359 0.4530  Hip-Hop
# 36621 0.1850  Rock
# 25455 0.4060  Rap
# 46541 0.1850  Hip-Hop
# 43558 0.0392  Classical
# 6346  0.6790  Anime
# 1573  0.1390  Electronic
# 9271  0.1390  Anime
# 44387 0.2160  Classical
# 22562 0.7600  Country

# %%
# удаляем дубликаты
genres_unique = genres_rnd[!duplicated(genres_rnd), ]

genres_unique
# Out:
#       instance_id artist_name
# 31722 27395       The Wood Brothers
# 4483  56677       Tropkillaz
# 14674 91335       La-33
# 37571 69786       Vampire Weekend
# 47583 77005       Yella Beezy
# 29473 52810       21 Savage
# 37204 25998       Bring Me The Horizon
# 34901 80522       Grand Funk Railroad
# 33883 73327       Badfinger
# 31371 70543       Lynyrd Skynyrd
# 40880 58144       Alexander Scriabin
# 45697 84475       A$AP Ferg
# 14314 24042       Leslie Odom Jr.
# 22268 68539       Josh Gracin
# 32976 74393       Santana
# 43483 84827       Wolfgang Amadeus Mozart
# 12678 82010       The Dramatics
# 8077  80580       majiko
# 47265 76196       Lecrae
# 19097 45010       Gorillaz
# 8641  58677       Ryuichi Sakamoto
# 32062 67618       Wendell B
# 38170 21354       Bryan Adams
# 38079 61223       The Neighbourhood
# 49952 21846       Frank Ocean
# 5843  87787       Mika Nakashima
# 5710  49994       empty_field
# 39491 90733       David Bowie
# 39866 59354       Jethro Tull
# 11649 24523       Paul Jackson, Jr.
# ⋮     ⋮           ⋮
# 38803 43788       BØRNS
# 30321 61992       Larkin Poe
# 21208 62171       Luke Bryan
# 22725 72992       The Judds
# 16576 61338       Jhene Aiko
# 5662  0.6990  Anime
# 20091 0.6530  Country
# 40953 0.3530  Classical
# 34228 0.7380  Blues
# 24272 0.5210  Country
# 37692 0.7360  Rock
# 46359 0.4530  Hip-Hop
# 36621 0.1850  Rock
# 25455 0.4060  Rap
# 46541 0.1850  Hip-Hop
# 43558 0.0392  Classical
# 6346  0.6790  Anime
# 1573  0.1390  Electronic
# 9271  0.1390  Anime
# 44387 0.2160  Classical
# 22562 0.7600  Country

# %%
# удаляем пустых артистов
empty_artist <- genres_unique[genres_unique$artist_name == "empty_field", ]
if (nrow(empty_artist) > 0) {
  genres_full <- genres_unique[genres_unique$artist_name != "empty_field", ]
}
genres_full
# Out:
#       instance_id artist_name
# 31722 27395       The Wood Brothers
# 4483  56677       Tropkillaz
# 14674 91335       La-33
# 37571 69786       Vampire Weekend
# 47583 77005       Yella Beezy
# 29473 52810       21 Savage
# 37204 25998       Bring Me The Horizon
# 34901 80522       Grand Funk Railroad
# 33883 73327       Badfinger
# 31371 70543       Lynyrd Skynyrd
# 40880 58144       Alexander Scriabin
# 45697 84475       A$AP Ferg
# 14314 24042       Leslie Odom Jr.
# 22268 68539       Josh Gracin
# 32976 74393       Santana
# 43483 84827       Wolfgang Amadeus Mozart
# 12678 82010       The Dramatics
# 8077  80580       majiko
# 47265 76196       Lecrae
# 19097 45010       Gorillaz
# 8641  58677       Ryuichi Sakamoto
# 32062 67618       Wendell B
# 38170 21354       Bryan Adams
# 38079 61223       The Neighbourhood
# 49952 21846       Frank Ocean
# 5843  87787       Mika Nakashima
# 39491 90733       David Bowie
# 39866 59354       Jethro Tull
# 11649 24523       Paul Jackson, Jr.
# 22394 44192       Brad Paisley
# ⋮     ⋮           ⋮
# 24256 36512       Struggle Jennings
# 29935 86694       K CAMP
# 9534  62016       RADWIMPS
# 38803 43788       BØRNS
# 30321 61992       Larkin Poe
# 21208 62171       Luke Bryan
# 22725 72992       The Judds
# 16576 61338       Jhene Aiko
# 9864  34431       Joe Hisaishi
# 10007 53044       FloFilz
# 42644 39235       Benjamin Britten
# 45155 21991       Mustard
# 17494 88942       Korn
# 27903 64646       A Boogie Wit da Hoodie
# 7653  31920       majiko
# 5662  40186       DREAMS COME TRUE
# 20091 82184       Lorne Greene
# 40953 90813       Franz Joseph Haydn
# 34228 34170       Heartless Bastards
# 24272 33143       Bobby Bare
# 37692 75000       AC/DC
# 46359 77681       Kodak Black
# 36621 35667       Bedroom
# 25455 82050       Migos
# 46541 22103       Lil Peep
# 6346  56638       UVERworld
# 1573  80967       QUIX
# 9271  35166       Masakatsu Takagi
# 44387 22491       Ludwig van Beethoven
# 22562 24318       Shotgun Rider
#       track_name
# 31722 Blue and Green
# 4483  Que Passa Amigo
# 14674 La Pantera Mambo
# 37571 Ottoman
# 47583 Keep It On Me
# 29473 4L
# 37204 medicine
# 34901 Closer To Home (I'm Your Captain) - Remastered
# 33883 I Miss You
# 31371 Was I Right Or Wrong - Demo Version
# 40880 Piano Concerto In F Sharp Minor, Op.20: 2. Andante
# 45697 Aww Yeah
# 14314 The Guilty Ones
# 22268 Brass Bed
# 32976 Oye Como Va
# 25455 D   0.1080    -5.456  Major 0.2010      145.905            4-Apr
# 46541 A   0.1060    -5.550  Minor 0.0320      115.037            4-Apr
# 6346  B   0.3580    -3.141  Minor 0.1560      92.491             4-Apr
# 1573  A#  0.6890    -2.679  Minor 0.0449      145.03799999999998 4-Apr
# 9271  C   0.1230   -29.916  Minor 0.0980      79.765             5-Apr
# 44387 C   0.0753   -27.302  Major 0.0546      127.295            4-Apr
# 22562 F#  0.1610    -6.688  Major 0.0349      161.922            4-Apr
#       valence music_genre
# 31722 0.2580  Blues
# 4483  0.0883  Electronic
# 14674 0.8190  Jazz
# 37571 0.7850  Rock
# 47583 0.1410  Hip-Hop
# 29473 0.0703  Rap
# 37204 0.3230  Rock
# 34901 0.4830  Blues
# 33883 0.1640  Blues
# 31371 0.6780  Blues
# 40880 0.0510  Classical
# 45697 0.1340  Hip-Hop
# 14314 0.3650  Jazz
# 22268 0.4540  Country
# 32976 0.9480  Blues
# 43483 0.3210  Classical
# 12678 0.7340  Jazz
# 8077  0.8090  Anime
# 47265 0.2140  Hip-Hop
# 19097 0.3940  Alternative
# 8641  0.3820  Anime
# 32062 0.7160  Blues
# 38170 0.3700  Rock
# 38079 0.3040  Rock
# 49952 0.4930  Hip-Hop
# 5843  0.6540  Anime
# 39491 0.7160  Rock
# 39866 0.8580  Rock
# 11649 0.7560  Jazz
# 22394 0.2850  Country
# ⋮     ⋮       ⋮
# 24256 0.418   Country
# 29935 0.830   Rap
# 9534  0.346   Anime
# 38803 0.902   Rock
# 30321 0.425   Blues
# 21208 0.871   Country
# 22725 0.588   Country
# 16576 0.349   Alternative
# 9864  0.608   Anime
# 10007 0.287   Jazz
# 42644 0.100   Classical
# 45155 0.137   Hip-Hop
# 17494 0.229   Alternative
# 27903 0.961   Rap
# 7653  0.616   Anime
# 5662  0.699   Anime
# 20091 0.653   Country
# 40953 0.353   Classical
# 34228 0.738   Blues
# 24272 0.521   Country
# 37692 0.736   Rock
# 46359 0.453   Hip-Hop
# 36621 0.185   Rock
# 25455 0.406   Rap
# 46541 0.185   Hip-Hop
# 6346  0.679   Anime
# 1573  0.139   Electronic
# 9271  0.139   Anime
# 44387 0.216   Classical
# 22562 0.760   Country

# %% [markdown]
# ### Задание 2
#
# 1. Выведите долю каждого жанра в датасете.
# 2. Покажите на горизонтальной столбиковой диаграмме распределение количества треков по жанрам. Выделите контрастным цветом жанр, в котором больше всего песен.
# 3. Найдите самый танцевальный жанр. У самого танцевального жанра среднее значение показателя danceability должно быть наивысшим.
# 4. Для каждого жанра определите, какая тональность в нем преобладает – количество треков какой тональность больше (минор или мажор).

# %%
# доля каждого жанра
all_genres = genres_full$music_genre
genre_counts <- table(all_genres[all_genres != ""])
genre_proportions <- data.frame(prop.table(genre_counts))

message("Доля каждого жанра в датасете:")
genre_proportions
# Out:
# Доля каждого жанра в датасете:
#    Var1        Freq
# 1  Alternative 0.10080984
# 2  Anime       0.10044173
# 3  Blues       0.09907446
# 4  Classical   0.09744426
# 5  Country     0.09681321
# 6  Electronic  0.10175642
# 7  Hip-Hop     0.09938999
# 8  Jazz        0.10459613
# 9  Rap         0.09602440
# 10 Rock        0.10364956

# %%
# столбиковая диаграмма
colors <- c(rep("grey", nrow(genre_proportions)))
colors[[which.max(genre_proportions$Freq)]] <- "red"

ggplot(data = genre_proportions, aes(x = Var1, y = Freq * nrow(genres_full), fill = Var1)) +
  coord_flip() + 
  geom_bar(stat = "identity") +
  xlab("Жанры") + ylab("Количество треков") +
  ggtitle("Распределение треков по жанрам") +
  scale_fill_manual(values = colors)
# Out:
# plot without title

# %%
# самый танцевальный жанр
mean_danceability <- aggregate(genres_full$danceability, by = list(genres_full$music_genre), mean)
most_danceable_genre <- mean_danceability$Group.1[which.max(mean_danceability$x)]

cat("Самый танцевальный жанр -", most_danceable_genre)
# Out:
# Самый танцевальный жанр - Hip-Hop

# %%
# тональности
get_tonal_mode <- function(all_genres) {
  major_count <- sum(all_genres$mode == "Major")
  minor_count <- sum(all_genres$mode == "Minor")
  
  if (major_count > minor_count) {
    tonal_mode <- "Major"
  } else if (minor_count > major_count) {
    tonal_mode <- "Minor"
  } else {
    tonal_mode <- "Equal"
  }

  return(data.frame(Genre = unique(all_genres$music_genre), mode = tonal_mode))
}

grouped <- by(genres_full, all_genres, get_tonal_mode)

result <- data.frame(do.call("rbind", grouped))
result <- result[2:nrow(result),]
rownames(result) <- NULL
result
# Out:
#   Genre      mode
# 1 Anime      Major
# 2 Blues      Major
# 3 Classical  Major
# 4 Country    Major
# 5 Electronic Major
# 6 Hip-Hop    Major
# 7 Jazz       Major
# 8 Rap        Major
# 9 Rock       Major

# %% [markdown]
# ### Задание 3
#
# 1. Выведите исполнителя, у которого больше всего треков в датасете. И того, у которого их меньше всех.
# 2. Покажите на горизонтральной столбиковой диаграмме топ-20 исполнителей. Изучите результат и сделайте выводы.

# %%
# наибольшее и наименьшее количество треков
most_tracks_artist <- names(sort(table(genres_full$artist_name), decreasing = TRUE))[1]
cat("Исполнитель с наибольшим количеством треков:", most_tracks_artist, "\n")

least_tracks_artist <- names(sort(table(genres_full$artist_name), decreasing = FALSE))[2]
cat("Исполнитель с наименьшим количеством треков:", least_tracks_artist, "\n")
# Out:
# Исполнитель с наибольшим количеством треков: Nobuo Uematsu
# Исполнитель с наименьшим количеством треков: 1000mods

# %%
# топ-20 исполнителей
top_artists <- data.frame(sort(table(genres_full$artist_name), decreasing = TRUE))
top_artists <- top_artists[0:20,]

ggplot(top_artists, aes(x = Var1, y = Freq)) +
  geom_bar(stat = "identity") +
  coord_flip() + 
  ggtitle("Топ-20 исполнителей по количеству песен") +
  xlab("Количество песен") +
  ylab("Исполнители")
# Out:
# plot without title

# %% [markdown]
# ### Задание 4

# %% [markdown]
# 1. Постройте корреляционную матрицу для характеристик треков. Между какими характеристиками сильная корреляция? Между какими слабая? Есть ли характеристики, между которыми корреляции практически нет.
# 2. Посчитайте корреляцию между популярностью (popularity) и длиной названия трека.

# %%
# считаем корреляции
chars <- c("popularity", "acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "liveness", "loudness", "speechiness", "valence")
data <- as.data.frame(na.omit(genres_full[, chars]))
correlation <- cor(data)

correlation
# Out:
#                  popularity  acousticness danceability duration_ms  energy
# popularity        1.00000000 -0.28204840   0.35340290  -0.088016869  0.21120413
# acousticness     -0.28204840  1.00000000  -0.33635918   0.066362073 -0.78922044
# danceability      0.35340290 -0.33635918   1.00000000  -0.160743762  0.25200705
# duration_ms      -0.08801687  0.06636207  -0.16074376   1.000000000 -0.07519976
# energy            0.21120413 -0.78922044   0.25200705  -0.075199759  1.00000000
# instrumentalness -0.36684233  0.38154140  -0.28696897   0.128385800 -0.38272099
# liveness         -0.04256861 -0.10877339  -0.05731439   0.007865253  0.18360067
# loudness          0.31740211 -0.73097421   0.37972313  -0.111833904  0.83776268
# speechiness       0.22949902 -0.15831256   0.27212816  -0.085862730  0.15846625
# valence           0.12197018 -0.26459916   0.44278969  -0.127638173  0.38099252
#                  instrumentalness liveness     loudness   speechiness
# popularity       -0.36684233      -0.042568614  0.3174021  0.22949902
# acousticness      0.38154140      -0.108773393 -0.7309742 -0.15831256
# danceability     -0.28696897      -0.057314393  0.3797231  0.27212816
# duration_ms       0.12838580       0.007865253 -0.1118339 -0.08586273
# energy           -0.38272099       0.183600672  0.8377627  0.15846625
# instrumentalness  1.00000000      -0.085349894 -0.5239732 -0.19988770
# liveness         -0.08534989       1.000000000  0.1222674  0.11207837
# loudness         -0.52397316       0.122267373  1.0000000  0.16458270
# speechiness      -0.19988770       0.112078370  0.1645827  1.00000000
# valence          -0.26164019       0.040068909  0.3339283  0.05926033
#                  valence
# popularity        0.12197018
# acousticness     -0.26459916
# danceability      0.44278969
# duration_ms      -0.12763817
# energy            0.38099252
# instrumentalness -0.26164019
# liveness          0.04006891
# loudness          0.33392833
# speechiness       0.05926033
# valence           1.00000000

# %%
install.packages("corrplot")
library(corrplot)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# corrplot 0.92 loaded

# %%
# корреляционная матрица
corrplot(correlation, type = "upper", method = "circle")
# Out:
# Plot with title “”

# %%
# корреляция между популярностью и длиной
data <- as.data.frame(na.omit(genres_full))
cor(data$popularity, nchar(data$track_name))
# Out:
# [1] -0.2242925

# %% [markdown]
# ### Задание 5
#
# Покажите на ящиковой диаграмме отношение популярности треков к жанру. Какие жанры похожи между собой?

# %%
# ящиковая диаграмма
ggplot(data=data, aes(x=music_genre, y=popularity, fill=music_genre)) + 
  geom_boxplot() +
  labs(title="Отношение популярности треков к жанру", x="Жанр", y="Популярность")
# Out:
# plot without title

# %% [markdown]
# ### Задание 7

# %% [markdown]
# На вертикальной столбиковой диаграмме для самого популярного (popularity) и самого непопулярного жанров покажите средние значения по всем характеристикам. Отрицательные и положительные значения характеристик показывайте разными цветами.

# %%
most <- genres_full$music_genre[which.max(genre_proportions$Freq)]
least <- genres_full$music_genre[which.min(genre_proportions$Freq)]

popular_genre <- genres_full[genres_full$music_genre == most, ]
unpopular_genre <- genres_full[genres_full$music_genre == least, ]

chars <- c("acousticness", "danceability", "energy", "instrumentalness", "key", "liveness", "loudness", "speechiness")

most_mean <- sapply(popular_genre[, chars], mean)
least_mean <- sapply(unpopular_genre[, chars], mean)

means_df <- data.frame(
  characteristic = chars,
  most_popular = most_mean,
  least_popular = least_mean
)

ggplot(means_df, aes(x = characteristic, y = least_popular, fill = characteristic)) +
  geom_col(aes(y = least_popular, fill = least_popular < 0), position = "dodge") +
  scale_fill_manual(values = c("green", "red")) +
  ggtitle("Средние значения по характеристикам для самого популярного и самого непопулярного жанров")
# Out:
# Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”
# Warning message:
# “Removed 1 rows containing missing values (`geom_col()`).”
# plot without title

# %% [markdown]
# ### Задание 8

# %% [markdown]
# 1. Добавьте в данные категориальный столбец `длительность_трека`, в котором будут значения: "короткая" (<=3min), "средняя" (>3min, <=5min), "длинная" (>5min).
# 2. Покажите график плотности распределения данных в столбце `loudness`, сгруппированных по категориям длительности.
# 3. На круговой диаграмме вида "пончик" покажите численное соотношение треков разной длительности.

# %%
# добавляем столбец
genres_full$длительность_трека <- cut(genres_full$duration_ms/1000/60, c(-Inf, 3, 5, Inf),
                             labels = c("короткая", "средняя", "длинная"))
head(genres_full)
# Out:
#       instance_id artist_name       track_name       popularity acousticness
# 31722 27395       The Wood Brothers Blue and Green   25         0.605000
# 4483  56677       Tropkillaz        Que Passa Amigo  41         0.009170
# 14674 91335       La-33             La Pantera Mambo 47         0.474000
# 37571 69786       Vampire Weekend   Ottoman          53         0.128000
# 47583 77005       Yella Beezy       Keep It On Me    54         0.002120
# 29473 52810       21 Savage         4L               72         0.000897
#       danceability duration_ms energy instrumentalness key liveness loudness
# 31722 0.499            -1      0.423  0.00e+00         C   0.0465   -7.347
# 4483  0.701        219025      0.844  1.90e-01         A   0.1130   -7.366
# 14674 0.782            -1      0.791  1.20e-03         C   0.0555   -6.321
# 37571 0.844        242267      0.625  3.99e-03         B   0.1020   -7.351
# 47583 0.693            -1      0.748  0.00e+00         C#  0.1110   -7.440
# 29473 0.879        288364      0.410  2.09e-05         G#  0.1080   -9.233
#       mode  speechiness tempo              obtained_date valence music_genre
# 31722 Major 0.0339      137.107            4-Apr         0.2580  Blues
# 4483  Major 0.0473      100.007            4-Apr         0.0883  Electronic
# 14674 Major 0.0383      99.992             4-Apr         0.8190  Jazz
# 37571 Minor 0.0272      ?                  4-Apr         0.7850  Rock
# 47583 Minor 0.1110      125.09299999999999 4-Apr         0.1410  Hip-Hop
# 29473 Major 0.5510      80.01100000000001  4-Apr         0.0703  Rap
#       длительность_трека
# 31722 короткая
# 4483  средняя
# 14674 короткая
# 37571 средняя
# 47583 короткая
# 29473 средняя

# %%
# график

p <- ggplot(genres_full, aes(x = loudness, fill = длительность_трека))
p <- p + geom_density(alpha = 0.4)
p <- p + labs(title = "Плотность распределения Loudness по категориям длительности треков",
              x = "Loudness",
              y = "Плотность") +
     scale_fill_manual(values = c("red", "green", "blue"),
                       labels = c("Короткая", "Средняя", "Длинная")) +
     theme_minimal()
print(p)
# Out:
# plot without title

# %%
# круговая диаграмма
ggplot(genres_full, aes(x = "", fill = длительность_трека)) + 
  geom_bar(width = 10, position = "fill") + 
  coord_polar(theta = "y") +
  scale_fill_manual(values = c("red", "green", "blue")) +
  labs(title = "Соотношение треков по длительности")
# Out:
# plot without title
